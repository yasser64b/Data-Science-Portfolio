# %% [markdown]
# # stock prices_Finance Data Project
#
# For this project I will focus on exploratory data analysis of stock prices.

# %% [markdown]
# ## Data
#
# I use pandas to directly read data from Google finance using pandas!

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data
#
# I need to get data using pandas datareader. I will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo

# %% [markdown]
# # Bank Data

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)
bank_stocks=pd.read_pickle('all_banks')

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %% [markdown]
# # EDA
#
#
#
# **  the max Close price for each bank's stock throughout the time period:**

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Returns for each bank's stock are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns=pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Returns']=bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Returns  C Returns  GS Returns  JPM Returns  MS Returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
#
#             WFC Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# 2006-01-05    -0.000951
# 2006-01-06     0.005714
# 2006-01-09     0.000000

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %% [markdown]
# what dates each bank stock had the best and worst single day returns

# %%
# Worst Drop (4 of them on Inauguration day)
returns.idxmin()
# Out:
# BAC Returns   2009-01-20
# C Returns     2011-05-06
# GS Returns    2009-01-20
# JPM Returns   2009-01-20
# MS Returns    2008-10-09
# WFC Returns   2009-01-20
# dtype: datetime64[ns]

# %%
# Best Single Day Gain
# citigroup stock split in May 2011, but also JPM day after inauguration.
returns.idxmax()
# Out:
# BAC Returns   2009-04-09
# C Returns     2011-05-09
# GS Returns    2008-11-24
# JPM Returns   2009-01-21
# MS Returns    2008-10-13
# WFC Returns   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# **  standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns.std() # Citigroup riskiest
# Out:
# BAC Returns    0.036650
# C Returns      0.179969
# GS Returns     0.025346
# JPM Returns    0.027656
# MS Returns     0.037820
# WFC Returns    0.030233
# dtype: float64

# %%
returns.ix['2015-01-01':'2015-12-31'].std() # Very similar risk profiles, but Morgan Stanley or BofA
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# BAC Returns    0.016163
# C Returns      0.015289
# GS Returns     0.014046
# JPM Returns    0.014017
# MS Returns     0.016249
# WFC Returns    0.012591
# dtype: float64

# %% [markdown]
# ### 2015 returns for Morgan Stanley

# %%
sns.distplot(returns.ix['2015-01-01':'2015-12-31']['MS Returns'],color='green',bins=100)
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ###  the 2008 returns for CitiGroup

# %%
sns.distplot(returns.ix['2008-01-01':'2008-12-31']['C Returns'], color='red',bins=100)
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ____
# # More Visualization
#
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12,4), label=tick)
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
# plotly
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="0c124de7-82a3-42da-aa87-58f87509e95a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0c124de7-82a3-42da-aa87-58f87509e95a")) {
#                     Plotly.newPlot(
#                         '0c124de7-82a3-42da-aa87-58f87509e95a',
# ...

# %% [markdown]
# ## Moving Averages
#
#  Moving averages for these stocks in the year 2008.
#
# ** Plotting the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
BAC=bank_stocks['BAC']

# %%
plt.figure(figsize=(12,6))
BAC['Close'].ix['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].ix['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ** Creating a heatmap of the correlation between the stocks Close Price.**

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# ** Useing clustermap to cluster the correlations together:**

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="611e8512-bc6e-4a47-9654-e4379da59a66" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("611e8512-bc6e-4a47-9654-e4379da59a66")) {
#                     Plotly.newPlot(
#                         '611e8512-bc6e-4a47-9654-e4379da59a66',
# ...

# %% [markdown]
# ** Use ing .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
BAC[['Open', 'High', 'Low', 'Close']].ix['2015-01-01':'2016-01-01'].iplot(kind='candle')
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="f76a1956-b4ca-43b3-b46d-9a571f5c5f52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f76a1956-b4ca-43b3-b46d-9a571f5c5f52")) {
#                     Plotly.newPlot(
#                         'f76a1956-b4ca-43b3-b46d-9a571f5c5f52',
# ...

# %% [markdown]
# ** Useing .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS=bank_stocks['MS']
MS['Close'].ix['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="be47f512-43a6-4414-b39d-1b90c45bf658" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("be47f512-43a6-4414-b39d-1b90c45bf658")) {
#                     Plotly.newPlot(
#                         'be47f512-43a6-4414-b39d-1b90c45bf658',
# ...

# %% [markdown]
# **Using .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BAC['Close'].ix['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# C:\Users\Yasser B\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# <div>
#
#
#             <div id="ffe41c86-4cff-4370-85f9-f70030fb6ce6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ffe41c86-4cff-4370-85f9-f70030fb6ce6")) {
#                     Plotly.newPlot(
#                         'ffe41c86-4cff-4370-85f9-f70030fb6ce6',
# ...
